// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта: Employee</h2>
//
// ----
//
// ### Вариант задания 3

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Employee в C#, который будет представлять информацию о
// сотрудниках компании. На основе этого класса разработать 2-3 производных
// класса, демонстрирующих принципы наследования и полиморфизма. В каждом из
// классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.
//
// Требования к базовому классу Employee:
//
// • Атрибуты: Имя (Name), Возраст (Age), Зарплата (Salary).
//
// • Методы:
//
// o GetInfo(): метод для получения информации о сотруднике в виде
// строки.
//
// o Work(): метод для вывода сообщения о выполнении рабочих
// обязанностей.
//
// o TakeVacation(): метод для вывода сообщения о взятии отпуска.
//
// Требования к производным классам:
//
// 1. Менеджер (Manager): Должен содержать дополнительные атрибуты, такие
// как Количество подчиненных (SubordinatesCount). Метод Work() должен быть
// переопределен для добавления информации о управлении командой.
//
// 2. Разработчик (Developer): Должен содержать дополнительные атрибуты,
// такие как Специализация (Specialization). Метод TakeVacation() должен быть
// переопределен для добавления информации о необходимости согласования
// отпуска с проектными сроками.
//
// 3. Дизайнер (Designer) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Стиль дизайна (DesignStyle).
// Метод Work() должен быть переопределен для добавления информации о
// работе над дизайн-проектами.
//
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой
//
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) и реализуйте простое, сложное и множественное наследование
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) и реализуйте полиморфизм с перекрытием и прегегрузкой методов, а также generic классы

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Employee
{
    public string Name { get; set; }
    public string Age { get; set; }
    public string Salary { get; set; }
    public string WStatus { get; set; }
    public string VStatus { get; set; }
    public string Position { get; set; }
    public string Department { get; set; }

    public Employee(string name, string age, string salary, string wstatus, string vstatus, string position, string department)
    {
        Name = name;
        Age = age;
        Salary = salary;
        WStatus = wstatus;
        VStatus = vstatus;
        Position = position;
        Department = department;
    }

    public virtual string GetInfo()
    {
        return $"Имя: {Name}, Возраст: {Age}, ЗП: {Salary}, Должность: {Position}, Отдел: {Department}";
    }

    public virtual string Work()
    {
        return $"Статус задач: {WStatus}";
    }

    public virtual string TakeVacation()
    {
        return $"Статус отпуска: {VStatus}";
    }

    public virtual string GetDepartmentInfo()
    {
        return $"Отдел: {Department}";
    }
}

public class Manager : Employee
{
    public string SubordinatesCount { get; set; }
    public int MeetingsScheduled { get; set; }

    public Manager(string name, string age, string salary, string wstatus, string vstatus, 
                   string subordinatesCount, int meetingsScheduled) 
        : base(name, age, salary, wstatus, vstatus, "Менеджер", "Управление")
    {
        SubordinatesCount = subordinatesCount;
        MeetingsScheduled = meetingsScheduled;
    }

    public override string Work()
    {
        return $"Статус: {WStatus}, Количество подчиненных: {SubordinatesCount}, Запланированные встречи: {MeetingsScheduled}";
    }

    public string ConductMeeting()
    {
        return "Проведение встречи...";
    }
}

public class EmployeeList<T> where T : Employee
{
    private List<T> employees = new List<T>();

    public void AddEmployee(T employee)
    {
        employees.Add(employee);
        Console.WriteLine($"Сотрудник {employee.Name} добавлен в список.");
    }

    public void RemoveEmployee(T employee)
    {
        if (employees.Remove(employee))
        {
            Console.WriteLine($"Сотрудник {employee.Name} удален из списка.");
        }
        else
        {
            Console.WriteLine($"Сотрудник {employee.Name} не найден в списке.");
        }
    }

    public void DisplayAll()
    {
        foreach (var employee in employees)
        {
            employee.Display();
        }
    }
}

public class Developer : Employee
{
    public string Specialization { get; set; }
    public int ProjectsCompleted { get; set; }

    public Developer(string name, string age, string salary, string wstatus, 
                     string vstatus, string specialization, int projectsCompleted) 
        : base(name, age, salary, wstatus, vstatus, "Разработчик", "Разработка")
    {
        Specialization = specialization;
        ProjectsCompleted = projectsCompleted;
    }

    public override string TakeVacation()
    {
        return $"{Specialization} - Статус отпуска: {VStatus}";
    }

    public void CodeReview()
    {
        Console.WriteLine("Проведение ревью кода...");
    }
}

public class Designer : Employee
{
    public string DesignStyle { get; set; }
    public int ProjectsInProgress { get; set; }

    public Designer(string name, string age, string salary, 
                    string wstatus, string vstatus, string designstyle,
                    int projectsInProgress) 
        : base(name, age, salary, wstatus, vstatus, "Дизайнер", "Дизайн")
    {
        DesignStyle = designstyle;
        ProjectsInProgress = projectsInProgress;
    }

    public override string Work()
    {
        return $"Стиль: {DesignStyle}, Статус задач: {WStatus}, Проекты в работе: {ProjectsInProgress}";
    }

   public void CreateMockup()
   {
       Console.WriteLine("Создание макета...");
   }
}

public class TeamLead : Manager
{
   public TeamLead(string name, string age, string salary,
                   string wstatus, string vstatus,
                   string subordinatesCount,
                   int meetingsScheduled) 
       : base(name, age, salary, wstatus, vstatus,
              subordinatesCount, meetingsScheduled)
   {
   }

   public void MentorTeam()
   {
       Console.WriteLine("Наставничество команды...");
   }
}

public interface IReportable
{
   void GenerateReport();
}

public class ReportingManager : Manager, IReportable
{
   public ReportingManager(string name,
                           string age,
                           string salary,
                           string wstatus,
                           string vstatus,
                           string subordinatesCount,
                           int meetingsScheduled): base(name, age, salary, wstatus, vstatus,
              subordinatesCount, meetingsScheduled)
   {
   }

   public void GenerateReport()
   {
       Console.WriteLine("Генерация отчета...");
   }
}

Manager _manager = new Manager("Азимбек", "46", "16859 руб", "63%", "В процессе работы", "2", 5);
Console.WriteLine(_manager.GetInfo());
Console.WriteLine(_manager.TakeVacation());
Console.WriteLine(_manager.Work());
Console.WriteLine(_manager.ConductMeeting());
Console.WriteLine();

Developer _developer = new Developer("Всеволод", "76", "83650 руб", "100%", "В отпуске", "Графический разработчик", 10);
Console.WriteLine(_developer.GetInfo());
Console.WriteLine(_developer.TakeVacation());
_developer.CodeReview();
Console.WriteLine();

Designer _designer = new Designer("Джошуа", "27", "56235 руб", "100%", "В отпуске", "Барокко", 3);
Console.WriteLine(_designer.GetInfo());
Console.WriteLine(_designer.TakeVacation());
Console.WriteLine(_designer.Work());
_designer.CreateMockup();
Console.WriteLine();

TeamLead _teamLead = new TeamLead("Равшан", "35", "120000 руб", "75%", "В процессе работы", "5", 3);
Console.WriteLine(_teamLead.GetInfo());
Console.WriteLine(_teamLead.Work());
_teamLead.MentorTeam();
Console.WriteLine();

ReportingManager _reportingManager = new ReportingManager("Рубик", "40", "150000 руб", "80%", "В процессе работы", "8", 4);
Console.WriteLine(_reportingManager.GetInfo());
Console.WriteLine(_reportingManager.Work());
_reportingManager.GenerateReport();

EmployeeList<Employee> employeeList = new EmployeeList<Employee>();

Manager first = new Manager("Ратибор", "46", "16859 руб", "63%", "В процессе работы", "1", 4);
Developer second = new Developer("Доброжир", "76", "83650 руб", "100%", "В отпуске", "Графический разработчик", 19);
Designer third = new Designer("Гостомысл", "27", "56235 руб", "100%", "В отпуске", "Античный", 2);

employeeList.AddEmployee(first);
employeeList.AddEmployee(second);
employeeList.AddEmployee(third);

Console.WriteLine("Список сотрудников:");
employeeList.DisplayAll();

employeeList.RemoveEmployee(third);
employeeList.RemoveEmployee(third);

Console.WriteLine("Список сотрудников:");
employeeList.DisplayAll();
// Out:
// Имя: Азимбек, Возраст: 46, ЗП: 16859 руб, Должность: Менеджер, Отдел: Управление
// Статус отпуска: В процессе работы
// Статус: 63%, Количество подчиненных: 2, Запланированные встречи: 5
// Проведение встречи...
//
// Имя: Всеволод, Возраст: 76, ЗП: 83650 руб, Должность: Разработчик, Отдел: Разработка
// Графический разработчик - Статус отпуска: В отпуске
// Проведение ревью кода...
//
// Имя: Джошуа, Возраст: 27, ЗП: 56235 руб, Должность: Дизайнер, Отдел: Дизайн
// Статус отпуска: В отпуске
// Стиль: Барокко, Статус задач: 100%, Проекты в работе: 3
// Создание макета...
//
// Имя: Равшан, Возраст: 35, ЗП: 120000 руб, Должность: Менеджер, Отдел: Управление
// Статус: 75%, Количество подчиненных: 5, Запланированные встречи: 3
// Наставничество команды...
//
// Имя: Рубик, Возраст: 40, ЗП: 150000 руб, Должность: Менеджер, Отдел: Управление
// Статус: 80%, Количество подчиненных: 8, Запланированные встречи: 4
// Генерация отчета...
// Сотрудник Ратибор добавлен в список.
// ...
